# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os
import sklearn
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d import Axes3D
from sklearn.manifold import TSNE, Isomap, SpectralEmbedding

sys.path.insert(1, os.path.join(sys.path[0], ".."))
sys.path.append('../../')
from reproduction.pipeline import load as pipeline
from reproduction import analysis
from reproduction.analysis import AEData

# %%
model_dir = "/home/rlourenco/rdcep_clouds/output/m9-22_oceans/"

with open(model_dir + "encoder.json", "r") as f:
    ae = tf.keras.models.model_from_json(f.read())
ae.load_weights(model_dir + "encoder.h5")
# Out:
# /home/rlourenco/miniconda3/envs/clouds-analysis-cpu/lib/python3.6/site-packages/tensorflow/python/keras/layers/core.py:764: UserWarning: models is not loaded, but a Lambda layer uses it. It may cause errors.
#   , UserWarning)

# %%
data = AEData(
    dataset=pipeline.load_data(
        data_glob="/project/foster/clouds/data/2015_05/*.tfrecord",
        shape=(128, 128, 7),
        batch_size=32,
        read_threads=4,
        shuffle_buffer_size=100,
        prefetch=2
    ),
    fields=["b%d"%(i+1) for i in range(7)],
    n=3000
)
# Out:
# WARNING:tensorflow:From ../../reproduction/pipeline/load.py:152: batch_and_drop_remainder (from tensorflow.contrib.data.python.ops.batching) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.batch(..., drop_remainder=True)`.

# %% [markdown]
# # PCA Anaysis

# %%
model_dir = "/home/rlourenco/rdcep_clouds/output/m9-22_oceans/"

def load_model(mname, summary=True):
    with open(mname + ".json", "r") as f:
        m = tf.keras.models.model_from_json(f.read())
    m.load_weights(mname + ".h5")
    m.summary()
    return m  

encoder = load_model(model_dir + "encoder")
decoder = load_model(model_dir + "decoder")

data.raw_encs = encoder.predict(data.imgs)
print('raw_encs: ',data.raw_encs.shape)
data.ae_imgs = decoder.predict(data.raw_encs)
print('ae_imgs: ',data.ae_imgs.shape)
data.encs = data.ae_imgs.mean(axis=(1,2))
print('encs: ',data.encs.shape)
data.compute_pca()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      (None, 128, 128, 7)  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 16) 1024        encoder_input[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 128, 128, 16) 0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 16)   2320        leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 64, 64, 16)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 16)   2320        leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 64, 64, 16)   0           conv2d_2[0][0]
#                                                                  conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 64, 64, 16)   64          lambda[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 64, 64, 16)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 32)   4640        leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 32, 32, 32)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 32)   9248        leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 32, 32, 32)   0           conv2d_4[0][0]
#                                                                  batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 32)   128         lambda_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 32, 32, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 64)   18496       leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 16, 16, 64)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 64)   36928       leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 16, 16, 64)   0           conv2d_6[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 16, 16, 64)   256         lambda_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 16, 16, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 128)    73856       leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 8, 8, 128)    0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 128)    147584      leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 8, 8, 128)    0           conv2d_8[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 8, 8, 128)    512         lambda_3[0][0]
# ==================================================================================================
# Total params: 297,376
# Trainable params: 296,896
# Non-trainable params: 480
# __________________________________________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# decoder_input (InputLayer)      (None, 8, 8, 128)    0
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 8, 8, 128)    0           decoder_input[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 16, 16, 128)  147584      leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 16, 16, 128)  0           conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 128)  147584      leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 16, 16, 128)  0           conv2d_9[0][0]
#                                                                  decoder_input[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 128)  512         lambda_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 16, 16, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 32, 32, 64)   73792       leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 32, 32, 64)   0           conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 64)   36928       leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 32, 32, 64)   0           conv2d_10[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 64)   256         lambda_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 32, 32, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 64, 64, 32)   18464       leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 64, 64, 32)   0           conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 64, 64, 32)   9248        leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 64, 64, 32)   0           conv2d_11[0][0]
#                                                                  batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, 64, 32)   128         lambda_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 64, 64, 32)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 128, 128, 16) 4624        leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 128, 128, 16) 0           conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 128, 128, 16) 2320        leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 128, 128, 16) 0           conv2d_12[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 128, 128, 16) 64          lambda_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 128, 128, 16) 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# reconstructed (Conv2D)          (None, 128, 128, 7)  119         leaky_re_lu_16[0][0]
# ==================================================================================================
# Total params: 441,623
# Trainable params: 441,143
# Non-trainable params: 480
# __________________________________________________________________________________________________
# raw_encs:  (3000, 8, 8, 128)
# ae_imgs:  (3000, 128, 128, 7)
# encs:  (3000, 7)

# %%
data.plot_pca_projection(data.encs, "colored by image mean", width=6, c=data.imgs.mean(axis=(1,2,3)))

# %%
data.plot_pca_projection(data.encs, "colored by image stdev", width=6, c=data.imgs.std(axis=(1,2,3)))

# %%
data.plot_pca_projection(
    data.encs, "colored by mean img color", width=6, cbar=False,
    color=data.colored_imgs.mean(axis=(1,2))
)

# %%
data.encs.shape
# Out:
# (3000, 7)

# %%
# %matplotlib inline
lmap = {n: i for i,n in enumerate(set(data.names))}
label = [lmap[l] for l in data.names]
data.plot_pca_projection(data.encs, "colored by input swath", width=6, c=label[:3000])

# %%
def colored_embedding(emb, titles_and_kwargs, nrows=2, ncols=2, width=6):
    fig = plt.figure(figsize=(width * nrows , width * ncols))
    
    for i, (tit, kwargs) in enumerate(titles_and_kwargs):
        a = fig.add_subplot(nrows, ncols, i+1, projection="3d")
        a.scatter(*emb.T, **kwargs)
        a.set_title(tit)

# %%
main_plots =  [
    ("colored by patch mean", {"c": data.imgs.mean(axis=(1,2,3))}),
    ("colored by patch stdev", {"c": data.imgs.std(axis=(1, 2, 3))}),
    ("colored by swath", {"c": label[:3000]}),
    ("colored by mean img color", {"color": data.colored_imgs.mean(axis=(1,2))})
]

# %%
# %matplotlib notebook
# %matplotlib notebook
# %matplotlib notebook

colored_embedding(data.pca_project(data.encs).T, main_plots)
# Out:
# <img src="data:image/png;base64,..." width="864">

# %% [markdown]
# ## IsoMap

# %%
isomap_emb = Isomap(n_components=3).fit_transform(data.encs)

# %%
# %matplotlib notebook
# %matplotlib notebook

colored_embedding(isomap_emb, main_plots)
# Out:
# <img src="data:image/png;base64,..." width="864">

# %% [markdown]
# ## TSNE Embedding

# %%
tsne_emb = TSNE(n_components=3).fit_transform(data.encs)

# %%
colored_embedding(tsne_emb, main_plots)
# Out:
# <img src="data:image/png;base64,..." width="864">

# %% [markdown]
# ## Spectral Embedding

# %%
spectral_emb = SpectralEmbedding(n_components=3).fit_transform(data.encs)

# %%
colored_embedding(spectral_emb, main_plots)
# Out:
# <img src="data:image/png;base64,..." width="864">
